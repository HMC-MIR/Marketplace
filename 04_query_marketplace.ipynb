# %% [markdown]
# ## Query Marketplace

# %% [markdown]
# This notebook constructs a "query marketplace", where our system selects the fingerprints with the highest utility to cost ratio at runtime and does lookups only on those fingerprints.

# %%
import pickle
import numpy as np
from ExtractBootlegScores import *
import itertools
import numba as nb
from numba import njit
from collections import defaultdict
import dill
from glob import iglob

# %% [markdown]
# **Load in databases and counts**

# %%
# this dictionary contains all the databases for each n-gram type included in our marketplace database
db_dir = "/data1/dyang/Marketplace_db/database/"

# %%
# this dictionary maps each n-gram type to its probability of correctness
probabilities_dir = "/data1/dyang/Marketplace_db/probabilities.pkl"

# %%
# this dictionary maps each number to the piece name (a string)
piece_mapping_dir = "/data1/dyang/Marketplace_db/num_to_piece_random.pkl"

# %%
d = {}

# %%
for filename in iglob(f"{db_dir}/*.pkl", recursive=True):
    combination = filename.split('/')[-1][:-4]
    with open(filename, "rb") as f:
        d[combination] = pickle.load(f)
    print(f"finished {combination}")
# Out:
# finished 015
# finished 014
# finished 035
# finished 02
# finished 03
# finished 05
# finished 013
# finished 04
# finished 023
# finished 025
# finished 045
# finished 034
# finished 01
# finished 012
# finished 0
# finished 024

# %%
with open(probabilities_dir, "rb") as f:
    utilities = pickle.load(f)

# %%
with open(piece_mapping_dir, 'rb') as f:
    num_to_piece = pickle.load(f)

# %%
combinations = []
for n_gram in range(1, 4):
    combinations += [[0] + list(tup) for tup in itertools.combinations(range(1, 6), n_gram-1)]

# %%
combinations = ["".join(str(num) for num in combination) for combination in combinations]

# %%
powers = 1 << np.arange(62)[::-1]

# %%
def compute_fingerprint(cols):
    fp = []
    equals_Zero = True
    for column in cols:
        hashint = int(column.dot(powers))
        fp.append(hashint)
        if hashint != 0:
            equals_Zero = False
    if equals_Zero == True:
        return None
    return tuple(fp)

# %% [markdown]
# Our utility to cost ratio is defined as the probability of correctness (utility) divided by the number of matches (cost), because the number of matches equals the number of lookups we would have to do for that fingerprint.

# %%
def utility(combination, matches):
    return utilities[combination] / matches

# %%
def get_ratios(bscore_query, rindex_dict):
    """Inputs: an L x 62 bootleg score query and our dictionary, where
               rindex_dict[fp] = (count, {dictionary of pieces and offsets})
        Output: a 16 X L table where each element is a tuple of (utility:cost ratio, combination, n_gram)"""
    l = len(bscore_query)
    # ratios[i][j] is a pair of (ratio, combination, fingerprint)
    ratios = np.array([[(0, None, None) for _ in range(l)] for _ in range(16)])
    for j in range(l):
        # calculate utility to cost ratio for all 16 n-grams
        for idx, combination in enumerate(combinations):
            cols = []
            # we need at least enough fingerprints for all the indices in our combination
            try:
                for i in combination:
                    cols.append(bscore_query[j+int(i)])
            except IndexError:
                continue
            fp = compute_fingerprint(cols)
            if not fp or combination not in rindex_dict or fp not in rindex_dict[combination]:
                continue
            matches = rindex_dict[combination][fp][0]
            if matches == 0:
                continue
            ratios[idx][j] = (utility(combination, matches), combination, fp)
    return ratios

# %%
def update_offset_dict(offset_dict, pieces_and_offsets, i, num_lookups):
    """Input: a dictionary mapping pieces to offsets for a given n-gram and the number of lookups we can do.
       Output: an updated dictionary of offsets containing all the lookups we just did. This dictionary
               will be used in the histogram of offsets."""
    if num_lookups == 0:
        return
    for piece in pieces_and_offsets:
        if num_lookups <= len(pieces_and_offsets[piece]):
            offset = [j - i for j in pieces_and_offsets[piece][:num_lookups]]
        else:
            offset = [j - i for j in pieces_and_offsets[piece]]
        offset_dict[num_to_piece[piece]].extend(offset)
        num_lookups -= len(pieces_and_offsets[piece])
        if num_lookups <= 0:
            break

# %%
def get_fingerprints(bscore_query, rindex_dict, ratios, runtime_budget):
    """This takes in a bootleg score for a query as its input, and does a certain number of lookups for each
       column of the bootleg score in accordance with our runtime budget. It then returns the updated dictionary of
       offsets containing all the lookups performed for the query, which is then used to compute the histogram of 
       offsets."""
    l = len(bscore_query)
    aisle_budget = runtime_budget // l
    cur_budget = aisle_budget
    offset_dict = defaultdict(list)
    matches_processed = 0
    for i in range(l):
        fingerprints = []
        col = ratios[:, i]
        lookups = sorted(col, key = lambda x: x[0], reverse = True)
        for _, combination, n_gram in lookups:
            if not n_gram or cur_budget < 0:
                break
            matches, pieces_and_offsets = rindex_dict[combination][n_gram]
            if cur_budget - matches < 0:
                num_lookups = cur_budget
            else:
                num_lookups = matches
            update_offset_dict(offset_dict, pieces_and_offsets, i, num_lookups)
            cur_budget -= num_lookups
            matches_processed += num_lookups
        cur_budget += aisle_budget
    return offset_dict, matches_processed

# %%
def rankHistograms(offset_dict, bin_size=10):
    """This implements the histogram of offsets method for ranking the predicted pieces."""
    bin_size = 3
    pieceScores = []
    for key, h in offset_dict.items():
        if not h:
            continue
        maxh = max(h)
        minh = min(h)
        hist = np.zeros(int((maxh-minh)/bin_size)+2)
        for i in h:
            hist[int((i-minh)/bin_size)] += 1
        score = np.max(hist)
        pieceScores.append((key, score))
            
    pieceScores = sorted(pieceScores, key = lambda x:x[1], reverse=True)
    return pieceScores

# %%
def processSingleQuery(imagefile, rindex, runtime_budget, outfile = None):
    """Inputs: a file representing a query image, a reverse index dictionary mapping each n-gram to its 
               offsets in IMSLP, and a runtime budget for the query.
       Output: a sorted list of predicted pieces and their scores based on the histogram of offsets method."""
    profileStart = time.time()
    
    # Get Bootleg Score
    bscore_query = processQuery(imagefile)
    bscore_query = bscore_query.T
    
    searchStart = time.time()
    # Generate and rank histograms
    
    ratios = get_ratios(bscore_query, rindex)
    offset_dict, matches_processed = get_fingerprints(bscore_query, rindex, ratios, runtime_budget)
    pieceScores = rankHistograms(offset_dict)
    # Profile & save to file
    profileEnd = time.time()
    
    profileDur = profileEnd - profileStart
    print(matches_processed)
    print(profileDur)
    saveToFile(outfile, imagefile, pieceScores, profileDur, matches_processed)
    return pieceScores

# %%
def saveToFile(outfile, imagefile, pieceScores, profileDur, matches_processed):
    if outfile:
        with open(outfile, 'wb') as f:
            query = os.path.splitext(os.path.basename(imagefile))[0]
            pickle.dump((query,pieceScores, profileDur, matches_processed),f)

# %%
processSingleQuery('data/CameraDataset/queries/p1_q1.jpg', d, 1000, outfile = None)
# Out:
# Processing data/CameraDataset/queries/p1_q1.jpg
# 749
# 0.8467371463775635
# [('p1', 13.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_00470', 9.0),
#  ('dGouin,_PierreNocturnes,_Op.9_112335', 8.0),
#  ('dGouin,_PierreNocturnes,_Op.9_34915', 7.0),
#  ('dGouin,_PierreNocturnes,_Op.9_00470', 6.0),
#  ('dGouin,_PierreNocturnes,_Op.9_86550', 5.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_86550', 4.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_113996', 3.0),
#  ('dGouin,_PierreNocturnes,_Op.9_34916', 3.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_34916', 3.0),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.22,_Op.54_51749', 3.0),
#  ('dGouin,_PierreNocturnes,_Op.9_113996', 3.0),
#  ('dMerkel,_Gustav_Adolf4_Pieces,_Op.74_367408', 3.0),
#  ('dHuber,_Hans10_Grosse_Et%C3%BCden,_Op.9_101631', 2.0),
#  ('dCzerny,_CarlThe_Art_of_Finger_Dexterity,_Op.740_04065', 2.0),
#  ('dLeschetizky,_TheodorSouvenirs_d%27Italie,_Op.39_502118', 2.0),
#  ('dCzerny,_CarlRondino_No.1_on_%27Cara_attendimi%27,_Op.22_355929', 2.0),
#  ('dSchumann,_RobertWaldszenen,_Op.82_271971', 2.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricWaltzes,_Op.64_400812', 2.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricRondo_in_C_minor,_Op.1_00487', 2.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricPiano_Sonata_No.3,_Op.58_79669', 2.0),
#  ('dDebussy,_ClaudeEtudes_246284', 2.0),
#  ('dMoszkowski,_Moritz2_Piano_Pieces,_Op.45_06879', 2.0),
#  ('dKrause,_Anton3_instructive_Sonaten,_Op.1_295295', 2.0),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.18,_Op.31_No.3_00018', 2.0),
#  ('dGouin,_PierreL%27office_pratique_de_l%27organiste_415233', 2.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_34915', 2.0),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.18,_Op.31_No.3_03168', 2.0),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.18,_Op.31_No.3_69580', 2.0),
#  ('dRubinstein,_Anton2_Morceaux,_Op.28_103335', 2.0),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.22,_Op.54_69584', 2.0),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.22,_Op.54_03183', 2.0),
#  ('dFuchs,_RobertTautropfen,_Op.112_185101', 2.0),
#  ('dTalexy,_AdrienLes_mouches_32340', 2.0),
#  ('dScriabin,_Aleksandr24_Preludes,_Op.11_75863', 2.0),
#  ('dBach,_Carl_Philipp_EmanuelKeyboard_Sonata_in_F_major,_H.269_54293', 2.0),
#  ('dAscher,_JosephLes_contemplations,_Op.54_377125', 1.0),
#  ('dMacDowell,_Edward6_Poems_after_Heine,_Op.31_219650', 1.0),
#  ('dHummel,_Johann_NepomukPiano_Sonata_No.1,_Op.2_04080', 1.0),
#  ('dBusoni,_FerruccioToccata,_BV_287_03658', 1.0),
#  ('dRachmaninoff,_Sergei2_Pieces_512543', 1.0),
#  ('dCzerny,_CarlPractical_Exercises_for_Beginners,_Op.599_86518', 1.0),
#  ('dKnuth,_J%C3%BCrgenPiano_Sonata_No.3,_Op.2_No.3_51972', 1.0),
#  ('dNollet,_Eug%C3%A8neLes_oiseaux,_Op.39_293620', 1.0),
#  ('dGodefroid,_F%C3%A9lixR%C3%AAverie-mazurke,_Op.169_260975', 1.0),
#  ('dAhrens,_HarryStandard_Graded_Course_of_Studies_for_the_Pianoforte_345823',
#   1.0),
#  ('dGottschalk,_Louis_MoreauLa_Favorita,_Op.68_20336', 1.0),
#  ('dGregoir,_Jacques%C3%89cole_moderne_du_piano,_Op.99_329314', 1.0),
#  ('dEvers,_CarlGrandes_Etudes,_Op.45_385470', 1.0),
#  ('dReynald,_GeorgBilder_in_T%C3%B6nen,_Op.6_507553', 1.0),
#  ('dIndy,_Vincent_d%27Tableaux_de_Voyage,_Op.33_22599', 1.0),
#  ('dRubinstein,_AntonKamenniy-Ostrov,_Op.10_06930', 1.0),
#  ('dGouin,_PierreNocturnes,_Op.9_80717', 1.0),
#  ('dMerkel,_Gustav_AdolfOrgan_Sonata_No.3,_Op.80_38081', 1.0),
#  ('dGouin,_PierrePractische_Orgelschule,_Op.55_417440', 1.0),
#  ('dBischoff,_HansStandard_Graded_Course_of_Studies_for_the_Pianoforte_345825',
#   1.0),
#  ('dMaylath,_HenryMerry_Thoughts_381556', 1.0),
#  ('dRaff,_JoachimSuite_No.7_for_Piano,_Op.204_322876', 1.0),
#  ('dCzerny,_CarlPiano_Sonata_No.10,_Op.268_267371', 1.0),
#  ('dLe_Carpentier,_Adolphe_ClaireStandard_Graded_Course_of_Studies_for_the_Pianoforte_345825',
#   1.0),
#  ('dBach,_Johann_SebastianFrench_Suite_No.1_in_D_minor,_BWV_812_02100', 1.0),
#  ('dMacDowell,_EdwardSecond_Modern_Suite,_Op.14_07943', 1.0),
#  ('dHandel,_George_Frideric8_Great_Suites,_HWV_426-433_111997', 1.0),
#  ('dFuller-Maitland,_John_AlexanderThe_Contemporaries_of_Purcell_438951', 1.0),
#  ('dMo%C3%B3r,_EmanuelPiano_Sonata_No.2,_Op.103_100781', 1.0),
#  ('dWood,_Charles16_Preludes_356780', 1.0),
#  ('dCzerny,_CarlThe_Art_of_Finger_Dexterity,_Op.740_12219', 1.0),
#  ('dSchumann,_RobertFantasiest%C3%BCcke,_Op.12_331140', 1.0),
#  ('dSchumann,_RobertAbegg_Variations,_Op.1_52347', 1.0),
#  ('dSchumann,_RobertWaldszenen,_Op.82_331142', 1.0),
#  ('dBrahms,_JohannesVariations_on_a_Hungarian_Song,_Op.21_No.2_138586', 1.0),
#  ('dWeber,_Carl_Maria_vonMax-Walzer,_J._Anh.81_99919', 1.0),
#  ('dGurlitt,_CorneliusT%C3%A4gliche_Studien,_Op.91_373943', 1.0),
#  ('dKruber,_LouisTraumbilder,_Op.58_378385', 1.0),
#  ('dKalkbrenner,_Friedrich_WilhelmFantaisie_sur_le_duo_des_cartes_de_%27Charles_VI%27,_Op.165_100790',
#   1.0),
#  ('dFarrenc,_Louise12_Etudes_de_dext%C3%A9rit%C3%A9,_Op.41_511753', 1.0),
#  ('dPigott,_FrancisThe_Contemporaries_of_Purcell_437831', 1.0),
#  ('dTalexy,_AdrienTremolo_35629', 1.0),
#  ('dHiller,_FerdinandWaltz,_Op.188_385624', 1.0),
#  ('dMartucci,_GiuseppeFantasia,_Op.51_97919', 1.0),
#  ('dDebussy,_ClaudeImages,_1ere_s%C3%A9rie_231788', 1.0),
#  ('dKalkbrenner,_Friedrich_WilhelmFantaisie_sur_le_duo_des_cartes_de_%27Charles_VI%27,_Op.165_100586',
#   1.0),
#  ('dHandel,_George_Frideric8_Great_Suites,_HWV_426-433_74358', 1.0),
#  ('dSchumann,_RobertHumoreske,_Op.20_289727', 1.0),
#  ('dElorduy,_Ernesto_MedinaMaria-Luisa_516577', 1.0),
#  ('dNeukomm,_SigismundGrand_Dramatic_Fantasia_69736', 1.0),
#  ('dLang,_JosephineArabeske_67590', 1.0),
#  ('dS%C3%A9rieux,_Ch.Le_concert_des_muses_129098', 1.0),
#  ('dSpindler,_FritzIm_Buchenhain,_Op.68_247571', 1.0),
#  ('dSaint-Sa%C3%ABns,_Camille3_Rhapsodies,_Op.7_290929', 1.0),
#  ('dElliott,_PercyThe_Gnomes%27_Wedding_321006', 1.0),
#  ('d%C5%A0%C5%A5astn%C3%BD,_Ludv%C3%ADkLe_concert_des_muses_129098', 1.0),
#  ('dHeyer,_OttoLe_concert_des_muses_129098', 1.0),
#  ('dWalther,_Johann_GottfriedConcerto_in_G_major_273885', 1.0),
#  ('dKalkbrenner,_Friedrich_Wilhelm25_Grandes_Etudes,_Op.143_413556', 1.0),
#  ('dGigout,_Eug%C3%A8neRhapsodie_sur_des_Airs_Catalans_305555', 1.0),
#  ('dElliott,_PercyThe_Gnomes%27_Wedding_320602', 1.0),
#  ('dCzerny,_CarlL%27%C3%A9cho_des_Alpes_Suisses,_Op.429_360592', 1.0),
#  ('dR%C3%A9e,_AntonParaphrase_438966', 1.0),
#  ('dKnuth,_J%C3%BCrgenPi%C3%A8ces_de_clavecin_avec_une_m%C3%A9thode_94815',
#   1.0),
#  ('dKalkbrenner,_Friedrich_Wilhelm25_Grandes_Etudes,_Op.143_09079', 1.0),
#  ('dMalats,_Joaqu%C3%ADnValse-Caprice,_Op.16_420363', 1.0),
#  ('dMoscheles,_IgnazLes_charmes_de_Londres,_Op.74_98265', 1.0),
#  ('dK%C3%B6hler,_L._UnicoLe_concert_des_muses_129098', 1.0),
#  ('dBrahms,_JohannesVariations_on_a_Hungarian_Song,_Op.21_No.2_08434', 1.0),
#  ('dMaylath,_HenryAgreeable_Surprise,_Op.302_380858', 1.0),
#  ('dScarlatti,_DomenicoKeyboard_Sonata_in_B_minor,_K.27_376370', 1.0),
#  ('dSchumann,_RobertDavidsb%C3%BCndlert%C3%A4nze,_Op.6_54412', 1.0),
#  ('dGouin,_Pierre%C3%89cole_d%27orgue_335913', 1.0),
#  ('dHummel,_Johann_NepomukRondo-Fantasie,_Op.19_78765', 1.0),
#  ('dMendelssohn,_Felix3_Caprices,_Op.33_52133', 1.0),
#  ('dBennett,_William_SterndaleSuite_de_pi%C3%A8ces,_Op.24_362476', 1.0),
#  ('dNielsen,_CarlTheme_and_Variations,_Op.40_33261', 1.0),
#  ('dMandyczewski,_EusebiusVariations_on_a_Hungarian_Song,_Op.21_No.2_08434',
#   1.0),
#  ('dFarrenc,_Louise12_Etudes_de_dext%C3%A9rit%C3%A9,_Op.41_489577', 1.0),
#  ('dBizet,_GeorgesRomances_sans_paroles_317322', 1.0),
#  ('dTurner,_WilliamThe_Contemporaries_of_Purcell_437831', 1.0),
#  ('dScriabin,_Aleksandr10_Mazurkas,_Op.3_06082', 1.0),
#  ('dScriabin,_Aleksandr10_Mazurkas,_Op.3_398229', 1.0),
#  ('dWels,_CharlesMocking_Bird_Galop,_Op.92_113824', 1.0),
#  ('dGrieg,_EdvardHolberg_Suite,_Op.40_84779', 1.0),
#  ('dMullen,_Alfred_FredericDanish_Suite_299397', 1.0),
#  ('dSchumann,_RobertHumoreske,_Op.20_00716', 1.0),
#  ('dBeethoven,_Ludwig_vanVariations_and_Fugue_in_E-flat_major,_Op.35_217745',
#   1.0),
#  ('dDie%C3%9Fener,_GerhardThe_Contemporaries_of_Purcell_437831', 1.0),
#  ('dLeonhard,_Julius_EmilPiano_Sonata_quasi_Fantasia,_Op.5_413583', 1.0),
#  ('dLiszt,_FranzMephisto_Waltz_No.1,_S.514_14188', 1.0),
#  ('dGade,_NielsAkvareller,_Op.19_176746', 1.0),
#  ('dDana,_RuthCollection_of_Liszt_editions,_Volume_8_67095', 1.0),
#  ('dBach,_Johann_SebastianPrelude_in_A_minor,_BWV_922_03291', 1.0),
#  ('dMassenet,_Jules2_Impromptus_393055', 1.0),
#  ('dHubert,_AlbertLe_concert_des_muses_129098', 1.0),
#  ('dSchumann,_RobertIntermezzi,_Op.4_00719', 1.0),
#  ('dRachmaninoff,_SergeiMoments_musicaux,_Op.16_03737', 1.0),
#  ('dGrieg,_Edvard3_Piano_Pieces,_EG_110-112_00575', 1.0),
#  ('dB%C3%BClow,_Hans_von3_Valses_caract%C3%A9ristiques,_Op.18_198822', 1.0),
#  ('dSchumann,_RobertDavidsb%C3%BCndlert%C3%A4nze,_Op.6_54411', 1.0),
#  ('dKnuth,_J%C3%BCrgen3_M%C3%A9lodies,_Op.4_78448', 1.0),
#  ('dNetzel,_Laura6_Morceaux,_Op.57_416347', 1.0),
#  ('dBeliczay,_Gyula12_Grandes_%C3%89tudes,_Op.52_481414', 1.0),
#  ('dKalkbrenner,_Friedrich_WilhelmLes_Nationalit%C3%A9s_musicales,_Op.184_09082',
#   1.0),
#  ('dStudniczka,_V.Le_concert_des_muses_129098', 1.0),
#  ('dRoyer,_Joseph-Nicolas-PancracePi%C3%A8ces_de_clavecin_300147', 1.0),
#  ('dOsten,_Fr._vonLe_concert_des_muses_129098', 1.0),
#  ('dHensel,_Fanny3_M%C3%A9lodies,_Op.4_78449', 1.0),
#  ('dHillemacher,_Lucien_Joseph_Edouard20_Pi%C3%A8ces_nouvelles_86117', 1.0),
#  ('dMaylath,_HenryJust_you_Dare!_381537', 1.0),
#  ('dLiszt,_FranzHarmonies_po%C3%A9tiques_et_religieuses_III,_S.173_00398',
#   1.0),
#  ('dCramer,_Johann_BaptistStudio_per_il_pianoforte,_Op.50_398874', 1.0),
#  ('dMozart,_Wolfgang_AmadeusPiano_Sonata_No.9_in_D_major,_K.31170207', 1.0),
#  ('dFranck,_C%C3%A9sarPr%C3%A9lude,_Choral_et_Fugue_03211', 1.0),
#  ('dAntalffy-Zsiross,_Dezs%C5%91Festa_Bucolica_296045', 1.0),
#  ('dClementi,_Muzio3_Keyboard_Sonatas,_Op.37_175522', 1.0),
#  ('dRudorff,_ErnstVariations_brillantes,_Op.12_143191', 1.0),
#  ('dCzerny,_CarlThe_School_of_Embellishments,_Op.355_310385', 1.0),
#  ('dReinecke,_CarlVariations_brillantes,_Op.12_86590', 1.0),
#  ('dKirchner,_Theodor60_Preludes,_Op.65_08276', 1.0),
#  ('dKolb,_Julius_vonSouvenir_des_montagnes,_Op.10_508080', 1.0),
#  ('dAlkan,_Charles-ValentinGrande_Sonate_%27Les_Quatre_Ages%27,_Op.33_309093',
#   1.0),
#  ('dKuhlau,_Friedrich12_Waltzes_for_Piano,_WoO_212_437999', 1.0),
#  ('dLysenko,_MykolaScherzo_h%C3%A9ro%C3%AFque,_Op.25_164581', 1.0),
#  ('dPachelbel,_Wilhelm_HieronymusToccata_in_G_major_275320', 1.0),
#  ('dReger,_MaxChoralfantasie_%C3%BCber_%22Freu_dich_sehr,_o_meine_Seele%22,_Op.30_04314',
#   1.0),
#  ('dLa_Tombelle,_Fernand_deRapsodie_b%C3%A9arnaise_287826', 1.0),
#  ('dGouin,_PierrePraeludium_in_G_major_97961', 1.0),
#  ('dScriabin,_Aleksandr12_Etudes,_Op.8_263772', 1.0),
#  ('dKrzy%C5%BCanowski,_Ignacy2_Mazourkas,_Op.10_501681', 1.0),
#  ('dKullak,_Theodor2_%C3%89tudes_de_Concert,_Op.2_365227', 1.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ric%C3%89tudes,_Op.25_447366', 1.0),
#  ('dMendelssohn,_FelixCapriccio,_Op.118_109262', 1.0),
#  ('dMoszkowski,_Moritz15_Etudes_de_Virtuosit%C3%A9,_Op.72_02806', 1.0),
#  ('dPachelbel,_Wilhelm_HieronymusPrelude_and_Fugue_in_C_major_453369', 1.0),
#  ('dDussek,_Jan_LadislavPiano_Sonata_No.29,_Op.5_No.3_399007', 1.0),
#  ('dRavina,_Jean_Henri12_Etudes_de_Concert,_Op.1_19559', 1.0),
#  ('dEgeberg,_Fredrikke6_Sange_uden_Ord_294335', 1.0),
#  ('dStrang,_Samuel_TudorCantique_d%27amour_101497', 1.0),
#  ('dMerkel,_Gustav_AdolfOrgelschule,_Op.177_290436', 1.0),
#  ('dRamenti,_H._D.Pas_de_Quatre_432994', 1.0),
#  ('dMarmontel,_Antoine_Fran%C3%A7ois24_Etudes_caracteristiques,_Op.25_09303',
#   1.0),
#  ('dReger,_MaxOrgan_Sonata_No.2,_Op.60_05900', 1.0),
#  ('dCzerny,_CarlSystematische_Anleitung_zum_Fantasieren_auf_dem_Pianoforte,_Op.200_234630',
#   1.0),
#  ('dHiller,_FerdinandEtudes,_Op.15_08938', 1.0),
#  ('dScharwenka,_Xaver6_Phantasiest%C3%BCcke,_Op.50_07398', 1.0),
#  ('dMandyczewski,_EusebiusVariations_on_a_Hungarian_Song,_Op.21_No.2_22893',
#   1.0),
#  ('dBuck,_DudleyWedding_March,_Op.44_268224', 1.0),
#  ('dHiller,_FerdinandEtudes,_Op.15_08937', 1.0),
#  ('dMilchmeyer,_Johann_PeterDie_wahre_Art_das_Pianoforte_zu_spielen_53825',
#   1.0),
#  ('dMerkel,_Gustav_AdolfBagatellen,_Op.81_422239', 1.0),
#  ('dStarke,_FriedrichWiener_Pianoforte_Schule,_Op.108_495094', 1.0),
#  ('dGouin,_PierrePi%C3%A8ces_d%27orgue_attribu%C3%A9es_%C3%A0_Leb%C3%A8gue_03932',
#   1.0),
#  ('dMayer,_CharlesFleurs_d%27automne,_Op.210_357712', 1.0),
#  ('dWidor,_Charles-MarieValses,_Op.71_206472', 1.0),
#  ('dMiddelschulte,_WilhelmPassacaglia_in_D_minor_390841', 1.0),
#  ('dCzerny,_CarlDivertissement_brillant_et_facile,_Op.209_356005', 1.0),
#  ('dBalmer,_CharlesThou_Art_Gone_from_My_Gaze_76163', 1.0),
#  ('dMason,_WilliamTouch_and_Technic,_Op.44_220640', 1.0),
#  ('dMicha%C5%82owski,_AleksanderMazurka,_Op.18_357098', 1.0),
#  ('dBarbier,_JulesChanson_du_Printemps_53947', 1.0),
#  ('dWollenhaupt,_Hermann_AdolfGrande_valse_brillante,_Op.54_26858', 1.0),
#  ('dMoszkowski,_Moritz5_Klavierst%C3%BCcke,_Op.18_33662', 1.0),
#  ('dLoeschhorn,_Albert33_Etudes_progressives_et_doigt%C3%A9es,_Op.66_278077',
#   1.0),
#  ('dBach,_Johann_Sebastian6_Partitas,_BWV_825-830_73879', 1.0),
#  ('dTurner,_WilliamThe_Contemporaries_of_Purcell_438951', 1.0),
#  ('dRudorff,_ErnstWaltzes,_Op.64_51545', 1.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricWaltzes,_Op.64_65956', 1.0),
#  ('dD%C3%B6hler,_TheodorRomance_sans_paroles_111234', 1.0),
#  ('dMandyczewski,_Eusebius8_Klavierst%C3%BCcke,_Op.76_84325', 1.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricPolonaises,_Op.26_85661', 1.0),
#  ('dChavagnat,_EdouardLes_ailes,_Op.166_95911', 1.0),
#  ('dPaufler,_Christian_HeinrichAlbum_of_Favorite_Songs_387739', 1.0),
#  ('dMullen,_Alfred_FredericNorwegian_Dances_301294', 1.0),
#  ('dLiszt,_FranzApparitions,_S.155_55553', 1.0),
#  ('dOsten,_Fr._vonLe_concert_des_muses_129104', 1.0),
#  ('dGouin,_Pierre6_Offertoires,_Op.35_263598', 1.0),
#  ('dPeterson-Berger,_WilhelmI_somras_434832', 1.0),
#  ('dStanford,_Charles_Villiers6_Occasional_Preludes,_Op.182_383245', 1.0),
#  ('dMendelssohn,_FelixPrelude_and_Fugue,_WoO_13_09368', 1.0),
#  ('dRavel,_MauriceMiroirs_02693', 1.0),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.9,_Op.14_No.1_243295', 1.0),
#  ('dKjerulf,_Halfdan6_Neue_Skizzen,_Op.12_09249', 1.0),
#  ('dWieniawski,_J%C3%B3zefPolka_brillante,_Op.11_444958', 1.0),
#  ('dSchubert,_FranzPiano_Sonata_No.18,_D.894_00359', 1.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricBolero,_Op.19_114991', 1.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricBolero,_Op.19_143201', 1.0),
#  ('dCerruti,_Giuseppe12_Sonate_per_i_principali_Registri_76134', 1.0),
#  ('dFibich,_Zden%C4%9BkMoods,_Impressions,_and_Souvenirs,_Op.47_76219', 1.0),
#  ('dKessler,_Joseph_Christoph2_Nocturnes_pour_piano,_Op.48_429784', 1.0),
#  ('dTaigner,_FerdinandWiener_Pfennig-Magazin_365664', 1.0),
#  ('dKlengel,_August_AlexanderPolonaise_in_E_major,_Op.8_78399', 1.0),
#  ('dKirchner,_Theodor100_Kleine_Studien,_Op.71_14694', 1.0),
#  ('dBuxtehude,_DietrichIch_dank_dir,_lieber_Herre,_BuxWV_194_483752', 1.0),
#  ('dClementi,_Muzio2_Piano_Sonatas_and_2_Capriccios,_Op.34_22784', 1.0),
#  ('dReinhold,_HugoSuite_mignonne,_Op.45_388118', 1.0),
#  ('dClementi,_MuzioPiano_Sonata_No.1,_Op.2_No.2_55220', 1.0),
#  ('dBairstow,_Edward_CuthbertPrelude_in_C_major_382394', 1.0),
#  ('dKri%C3%A9ger,_GeorgesToccata_in_E_minor_316004', 1.0),
#  ('dClementi,_Muzio3_Piano_Sonatas,_Op.33_63300', 1.0),
#  ('dFerguson,_Ludwig_Wilhelm_Tepper_vonVariations_sur_l%27air_%27Loin_de_toi_ma_Felicie%27_109449',
#   1.0),
#  ('dBach,_Johann_SebastianFantasia_in_G_major,_BWV_571_04353', 1.0),
#  ('dLeutner,_AlbertTroubadour-Quadrille,_Op.39_111399', 1.0),
#  ('dGouin,_PierreDas_wohltemperierte_Klavier_II,_BWV_870-893_55703', 1.0),
#  ('dAlkan,_Charles-Valentin3_Morceaux_dans_le_Genre_path%C3%A9tique,_Op.15_02657',
#   1.0),
#  ('dGottschalk,_Louis_MoreauLa_M%C3%A9lancolie_125508', 1.0),
#  ('dThalberg,_SigismondSouvenirs_d%27Am%C3%A9rique_11528', 1.0),
#  ('dSch%C3%BCtt,_EduardValses_dialogues,_Op.73_465999', 1.0),
#  ('dCzerny,_CarlDas_moderne_Klavierspiel,_Op.837_372511', 1.0),
#  ('dSchumann,_ClaraCaprices_en_forme_de_valses,_Op.2_374017', 1.0),
#  ('dColomer,_Blas_Mar%C3%ADa_deCaprice_concertant_361592', 1.0),
#  ('dAletter,_Wilhelm6_Kinderst%C3%BCcke_378217', 1.0),
#  ('dCosta_Nogueras,_VicenteLos_Pelotaris_397630', 1.0),
#  ('dSchumann,_RobertBunte_Bl%C3%A4tter,_Op.99_336376', 1.0),
#  ('dDebussy,_ClaudeEtudes_507725', 1.0),
#  ('dMoscheles,_IgnazSonate_m%C3%A9lancolique,_Op.49_10693', 1.0),
#  ('dGouin,_Pierre33_Portraits,_Op.101_295137', 1.0),
#  ('dWeyse,_Christoph_Ernst_Friedrich6_Allegros_di_bravura,_Op.1_34681', 1.0),
#  ('dWest,_George_FrederickBeatrice_349237', 1.0),
#  ('dVetter,_HermannImpromptu,_Op.15_488254', 1.0),
#  ('dHeinrich,_Anthony_Philip3_Images_of_Musical_Thought_107107', 1.0),
#  ('dKnuth,_J%C3%BCrgen6_Organ_Sonatas,_Op.65_58285', 1.0),
#  ('dCapocci,_FilippoOrgan_Sonata_No.1_309655', 1.0),
#  ('dJadin,_Hyacinthe3_Piano_Sonatas,_Op.4_34082', 1.0),
#  ('dComettant,_OscarHeures_d%27harmonie_373187', 1.0),
#  ('dClark,_Scotson15_Marches_for_Organ_207151', 1.0),
#  ('dBuxtehude,_DietrichDanket_dem_Herren,_denn_er_ist_sehr_freundlich,_BuxWV_181_483740',
#   1.0),
#  ('dLoder,_Edward_JamesIntroduction_and_Rondo_Brillant,_Op.17_290268', 1.0),
#  ('dPachelbel,_JohannRicercar_in_C_major,_P.418_452956', 1.0),
#  ('dSinding,_Christian5_Klavierst%C3%BCcke,_Op.97_07175', 1.0),
#  ('dGottschalk,_Louis_MoreauThe_Water_Sprite,_Op.27_07734', 1.0),
#  ('dCzerny,_Carl125_Passagen%C3%BCbungen,_Op.261_245853', 1.0),
#  ('dJensen,_AdolfErinnerungen,_Op.48_447399', 1.0),
#  ('dBach,_Johann_SebastianDas_wohltemperierte_Klavier_II,_BWV_870-893_69717',
#   1.0),
#  ('dGodefroid,_F%C3%A9lixLa_harpe_d%27or,_Op.89_260966', 1.0),
#  ('dGouin,_Pierre6_Chor%C3%A4le_von_verschiedener_Art,_BWV_645-650_301218',
#   1.0),
#  ('dBach,_Johann_SebastianDas_wohltemperierte_Klavier_II,_BWV_870-893_69276',
#   1.0),
#  ('dKalkbrenner,_Friedrich_WilhelmPiano_Sonata,_Op.56_09066', 1.0),
#  ('dGouin,_PierreDas_wohltemperierte_Klavier_II,_BWV_870-893_36340', 1.0),
#  ('dMeumann,_ErnestoCaprice,_Op.13_355343', 1.0),
#  ('dTchaikovsky,_Pyotr18_Pieces,_Op.72_17432', 1.0),
#  ('dAlwens,_CharlesValse_brillante_416430', 1.0),
#  ('dBach,_Carl_Philipp_EmanuelRondo_in_A_minor,_H.262_106187', 1.0),
#  ('dPaderewski,_Ignacy_JanVariations_et_fugue_sur_un_th%C3%A8me_original,_Op.23_236746',
#   1.0),
#  ('dSalom%C3%A9,_Th%C3%A9odore10_Pi%C3%A8ces,_Op.48_280017', 1.0),
#  ('dFaur%C3%A9,_GabrielBarcarolle_No.3,_Op.42_55625', 1.0),
#  ('dCapocci,_Filippo10_composizioni_per_organo_41648', 1.0),
#  ('dJonas,_Ernst8_Instructive_Compositions,_Op.42_253279', 1.0),
#  ('dH%C3%B6ger,_AntonEin_feste_Burg_ist_unser_Gott,_BuxWV_184_483803', 1.0),
#  ('dLiszt,_Franz3_Caprices-Valses,_S.214_58315', 1.0),
#  ('dDale,_BenjaminNight_Fancies_353324', 1.0),
#  ('dMaykapar,_SamuilSuite_mignonne,_Op.30_354495', 1.0),
#  ('dBrassin,_LouisAus_Richard_Wagner%27s_%27Der_Ring_des_Nibelungen%27_13527',
#   1.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricPreludes,_Op.28_85374', 1.0),
#  ('dLyapunov,_Sergey2_Pieces_from_Glinka%27s_%27Ruslan_and_Ludmilla%27,_Op.33_10321',
#   1.0),
#  ('dLyapunov,_Sergey12_%C3%89tudes_d%27ex%C3%A9cution_transcendante,_Op.11_01630',
#   1.0),
#  ('dRuthardt,_Adolf15_Studien_in_gebrochenen_Akkorden,_Op.45_348608', 1.0),
#  ('dLiszt,_FranzHungarian_Rhapsody_No.2,_S.24414927', 1.0),
#  ('dOuld,_Samuel_GregoryThe_Latin_Organist_293639', 1.0),
#  ('dLiszt,_FranzTechnische_Studien,_S.146_241444', 1.0),
#  ('dMerikanto,_Oskar2_Impromptus,_Op.44_519072', 1.0),
#  ('dHerz,_HenriDivertimento_No.1,_Op.15_14140', 1.0),
#  ('dSchumann,_RobertEtudes_after_Paganini_Caprices,_Op.3_54296', 1.0),
#  ('dBach,_Johann_SebastianHerr_Jesu_Christ,_dich_zu_uns_wend,_BWV_Anh.56_509029',
#   1.0),
#  ('dSchubert,_CamilleLa_Poste,_Op.39_32429', 1.0),
#  ('dSchubert,_CamilleLa_Poste,_Op.39_342344', 1.0),
#  ('dRudnick,_Wilhelm30_Choral-Vorspiele,_Op.70_324093', 1.0),
#  ('dKnuth,_J%C3%BCrgenPi%C3%A8ces_de_clavecin_avec_une_m%C3%A9thode_114240',
#   1.0),
#  ('dSchytte,_Ludvig8_Sketches,_Op.98A_91900', 1.0),
#  ('dGouin,_PierrePi%C3%A8ces_de_clavecin_avec_une_m%C3%A9thode_114240', 1.0),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.18,_Op.31_No.3_419639', 1.0),
#  ('dRubinstein,_Anton6_Etudes,_Op.81_348862', 1.0),
#  ('dArensky,_AntonPr%C3%A8s_de_la_mer,_Op.52_02724', 1.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricPreludes,_Op.28_79718', 1.0),
#  ('dGouin,_PierrePi%C3%A8ces_de_clavecin_avec_une_m%C3%A9thode_07867', 1.0),
#  ('dVilbac,_Renaud_deMazurka_de_salon_415520', 1.0),
#  ('dLiszt,_FranzHungarian_Rhapsody_No.2,_S.24467715', 1.0),
#  ('dSchumann,_RobertEtudes_after_Paganini_Caprices,_Op.3_00404', 1.0),
#  ('dSchneider,_Conrad_MichaelClavier_%C3%9Cbung_325252', 1.0),
#  ('dSchumann,_RobertEtudes_after_Paganini_Caprices,_Op.3_54920', 1.0),
#  ('dGouin,_PierrePreludes,_Op.28_79718', 1.0),
#  ('dCappelletti,_ArrigoAspiration_Religieuse_292214', 1.0),
#  ('dSchumann,_RobertEtudes_after_Paganini_Caprices,_Op.3_289896', 1.0),
#  ('dFradel,_CharlesPiano_Sonatinas,_Op.505_82119', 1.0),
#  ('dPeterson-Berger,_Wilhelm4_Danspoem_434818', 1.0),
#  ('dArensky,_Anton12_Etudes,_Op.74_64446', 1.0),
#  ('dSchytte,_Ludvig3_Etudes_de_Concert,_Op.48_412933', 1.0),
#  ('dSchytte,_Ludvig3_Etudes_de_Concert,_Op.48_522621', 1.0),
#  ('dKarg-Elert,_SigfridGradus_ad_Parnassum,_Op.95_108977', 1.0),
#  ('dSchumann,_RobertEtudes_after_Paganini_Caprices,_Op.3_54919', 1.0),
#  ('dClementi,_Muzio6_Piano_Sonatas,_Op.25_511131', 1.0),
#  ('dArensky,_Anton24_Morceaux_caract%C3%A9ristiques,_Op.36_518472', 1.0),
#  ('dFerlus,_CharlesLe_soldat_laboureur,_Op.50_259799', 1.0),
#  ('dSchumann,_RobertEtudes_after_Paganini_Caprices,_Op.3_52421', 1.0),
#  ('dArensky,_Anton24_Morceaux_caract%C3%A9ristiques,_Op.36_06466', 1.0),
#  ('dDana,_RuthCollection_of_Liszt_editions,_Volume_6_67715', 1.0),
#  ('dCramer,_Johann_BaptistDulce_et_utile,_Op.55_387315', 1.0),
#  ('dStanchinsky,_AlekseyCanon_in_B_minor_361057', 1.0),
#  ('dStanchinsky,_AlekseyCanon_in_B_minor_359791', 1.0),
#  ('dGouin,_PierrePremier_livre_de_pi%C3%A8ces_de_clavecin_107264', 1.0),
#  ('dKnuth,_J%C3%BCrgenPi%C3%A8ces_de_clavecin_avec_une_m%C3%A9thode_114239',
#   1.0),
#  ('dKnuth,_J%C3%BCrgenNotebooks_for_Anna_Magdalena_Bach_02320', 1.0),
#  ('dKnuth,_J%C3%BCrgenPi%C3%A8ces_de_clavecin_avec_une_m%C3%A9thode_07867',
#   1.0),
#  ('dHensel,_Fanny3_M%C3%A9lodies,_Op.4_78448', 1.0),
#  ('dGayrhos,_EugenPhantasiest%C3%BCckchen_f%C3%BCr_kleine_H%C3%A4nde,_Op.18_82613',
#   1.0),
#  ('dWickede,_Friedrich_von3_Morceaux_faciles,_Op.155_507208', 1.0),
#  ('dPachelbel,_JohannSuite_in_G_minor,_P.442_275735', 1.0),
#  ('p95', 1.0),
#  ('dDreyschock,_AlexanderSoir%C3%A9e_d%27hiver,_Op.92_375023', 1.0),
#  ('dMendelssohn,_FelixFantasie,_Op.28_53956', 1.0),
#  ('dClementi,_Muzio3_Keyboard_Sonatas,_Op.37_173434', 1.0),
#  ('dHewitt,_John_HillThe_Fall_of_Mexico_468775', 1.0),
#  ('dShenshin,_Aleksandr7_Preludes,_Op.3_337975', 1.0),
#  ('dBarbedette,_HippolyteBerceuse,_Op.150_203239', 1.0),
#  ('dWolfrum,_PhilippOrgan_Sonata_No.2,_Op.10_83330', 1.0),
#  ('dZilcher,_Paul8_Easy_Octave_Studies,_Op.49_379961', 1.0),
#  ('dSchubert,_Franz20_Minuets,_D.41_03150', 1.0),
#  ('dHaydn,_JosephKeyboard_Sonata_in_E_minor,_Hob.XVI:34_475089', 1.0),
#  ('dSchubert,_Franz20_Minuets,_D.41_53774', 1.0),
#  ('dFuchs,_RobertJugendalbum,_Op.47_63793', 1.0),
#  ('dReger,_MaxTr%C3%A4ume_am_Kamin,_Op.143_47273', 1.0),
#  ('dMariani,_AngeloBiblioteca_d%27oro_518180', 1.0),
#  ('dMontgeroult,_H%C3%A9l%C3%A8ne3_Sonatas,_Op.1_468990', 1.0),
#  ('dBrahms,_Johannes2_Rhapsodies,_Op.79_516783', 1.0),
#  ('dMandyczewski,_Eusebius2_Rhapsodies,_Op.79_08445', 1.0),
#  ('dMacFadyen,_AlexanderPiano_Sonata,_Op.21_97990', 1.0),
#  ('dFaur%C3%A9,_GabrielValse-Caprice_No.4,_Op.62_211922', 1.0),
#  ('dFranke,_MaxAus_der_Jugendzeit,_Op.56_387375', 1.0),
#  ('dBencini,_Pietro_PaoloBiblioteca_d%27oro_518180', 1.0),
#  ('dJeffery,_John_AlbertAlbum_of_Ten_Pieces_for_the_Pianoforte_by_American_Composers_303172',
#   1.0),
#  ('dFranck,_C%C3%A9sarFinal,_Op.21_208347', 1.0),
#  ('dMandyczewski,_Eusebius2_Rhapsodies,_Op.79_516783', 1.0),
#  ('dManfroce,_NicolaBiblioteca_d%27oro_18486', 1.0),
#  ('dHaydn,_JosephKeyboard_Sonata_in_G_minor,_Hob.XVI:44_475021', 1.0),
#  ('dOrefice,_Giuseppe_dell%27Biblioteca_d%27oro_18486', 1.0),
#  ('dJensen,_Niels_Peter6_Rondeaux_Faciles,_Op.13_21863', 1.0),
#  ('dDiabelli,_Anton2_Potpourris_aus_%27Rigoletto%27_109519', 1.0),
#  ('dHummel,_Johann_NepomukVariations_sur_un_theme_original,_Op.76_22010', 1.0),
#  ('dHiggs,_Henry_MarcellusOrgan_Sonata_in_C_minor_398351', 1.0),
#  ('dDraghi,_Giovanni_Battista6_Harpsichord_Suites_117681', 1.0),
#  ('dLongo,_AlessandroPiano_Sonata_No.1,_Op.32_366945', 1.0),
#  ('dBrahms,_JohannesScherzo,_Op.4_17725', 1.0),
#  ('dBrahms,_JohannesScherzo,_Op.4_22815', 1.0),
#  ('dBlumenfeld,_Felix2_Pieces,_Op.22_07188', 1.0),
#  ('dBossi,_Marco_EnricoEtude_Symphonique,_Op.78_13045', 1.0),
#  ('dKrzy%C5%BCanowski,_IgnacyGavotte,_Op.56_21462', 1.0),
#  ('dR%C3%B6ntgen,_JuliusDolce_far_niente,_Op.60_103577', 1.0),
#  ('dMandyczewski,_EusebiusScherzo,_Op.4_17725', 1.0),
#  ('dBach,_Johann_SebastianDas_Orgel-B%C3%BCchlein,_BWV_599-644_04104', 1.0),
#  ('dButler,_Thomas_Hamly3_Piano_Sonatas_374361', 1.0),
#  ('dCasalaina,_RiccardoOra_triste_430687', 1.0),
#  ('dHenselt,_Adolf_von10_Pieces_for_Piano,_Op.13_11113', 1.0),
#  ('dGouin,_PierreDas_Orgel-B%C3%BCchlein,_BWV_599-644_04104', 1.0),
#  ('dLitta,_PaoloTamariska_389936', 1.0),
#  ('dDebussy,_ClaudeImages,_2%C3%A8me_s%C3%A9rie_00508', 1.0),
#  ('dStenhammar,_WilhelmImpromptu_73405', 1.0),
#  ('dHess,_J._CharlesMorceau_de_salon_avec_final_en_carrillon_sur_%27Le_grand_Casimir%27_258962',
#   1.0),
#  ('dCui,_C%C3%A9sar3_Pieces_from_the_Last_Years_20540', 1.0),
#  ('dWidor,_Charles-MarieOrgan_Symphony_No.6,_Op.42_No.2_335745', 1.0),
#  ('dScriabin,_Aleksandr24_Preludes,_Op.11_75864', 1.0),
#  ('dRigel,_Henri_Joseph6_Harpsichord_Sonatas,_Op.1_356474', 1.0),
#  ('dAlbert,_Charles_d%27The_Regatta_Waltzes_202542', 1.0),
#  ('dHess,_J._CharlesSouvenir_de_%27Joconde%27_291724', 1.0),
#  ('dRocasSouvenez-vous_en_506651', 1.0),
#  ('dWinding,_August5_Klaverstykker_i_Etudeform,_Op.24_413597', 1.0),
#  ('dMoscheles,_Ignaz24_Etudes,_Op.70_25797', 1.0),
#  ('dSteibelt,_DanielThe_Conflagration_of_Moscow_485019', 1.0),
#  ('dYung,_AlfredLa_course_382181', 1.0),
#  ('dLiszt,_Franz%C3%89tude_en_douze_exercices,_S.136_54991', 1.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_112335', 1.0),
#  ('dGrieg,_EdvardNorwegian_Peasant_Dances,_Op.72_67453', 1.0),
#  ('dCramer,_Johann_BaptistNew_Practical_School,_Op.100_498853', 1.0),
#  ('dMacDowell,_EdwardPiano_Sonata_No.1,_Op.45_219692', 1.0),
#  ('dMozart,_Wolfgang_Amadeus12_Variations_on_%22Je_suis_Lindor%22,_K.35456888',
#   1.0),
#  ('dNilson,_LarsA_System_of_Technical_Studies_in_Pedal_Playing_for_the_Organ_172608',
#   1.0),
#  ('dMoser,_Hans_JoachimTabulatura_Nova,_SSWV_102-158_491924', 1.0),
#  ('dCzerny,_CarlThe_Art_of_Finger_Dexterity,_Op.740_12218', 1.0),
#  ('dGiese,_TheodorLe_concert_des_muses_129108', 1.0),
#  ('dS%C3%A9rieux,_Ch.Le_concert_des_muses_129108', 1.0),
#  ('dReger,_MaxVariations_and_Fugue_on_an_Original_Theme,_Op.73_05746', 1.0),
#  ('dScriabin,_AleksandrPiano_Sonata_No.4,_Op.30_10998', 1.0),
#  ('dWinkler,_Aleksandr3_Pieces,_Op.15_473456', 1.0),
#  ('dSchmitt,_AlphonsePr%C3%A9lude-Choral_283661', 1.0),
#  ('dBach,_Carl_Philipp_EmanuelKeyboard_Sonata_in_F_major,_H.55_256319', 1.0),
#  ('dEngelmann,_HansAwakening,_Op.620_No.2_388467', 1.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricFantaisie-impromptu,_Op.66_399500', 1.0),
#  ('dSchumann,_RobertPiano_Sonata_No.3,_Op.14_271030', 1.0),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricFantaisie-impromptu,_Op.66_86431', 1.0),
#  ('dBach,_Johann_SebastianAn_Wasserfl%C3%BCssen_Babylon,_BWV_653_494826', 1.0),
#  ('dSchneider,_FranzOrgelschule,_Op.177_290436', 1.0)]

# %%
def processQuery_wrapper(queryfile, rindex, outdir, runtime_budget):
    # wrapper for running multiple jobs in parallel
    basename = os.path.splitext(os.path.basename(queryfile))[0] # e.g. p1_q1
    hyp_outfile = "{}/{}.hyp".format(outdir, basename)
    piece = basename.split('_')[0]
    # might change later to print to outfile
    return processSingleQuery(queryfile, rindex, runtime_budget, hyp_outfile)

# %% [markdown]
# Here we set the runtime budget to 65000, which means we can process at most 65000 matches per query.

# %%
runtime_budget = 1000

# %%
query_list = '../Marketplace/cfg_files/scanned.train' # list of query images
outdir = f'/home/dyang/experiments_final/train/scanned1k' # where to save hypothesis output files

# %%
# prep output directory
if not os.path.isdir(outdir):
    os.makedirs(outdir)

# load reverse index. Recommend keeping load=False and loading it earlier.
load = False
if load:
    print("LOADING RINDEX")
    rindex1 = []
    with open(pickle_file, 'rb') as f:
        rindex1 = pickle.load(f)
    rindex_filter = rindex1

print("STARTING PROCESSING")
# number of cores to use
multiprocess = False
if multiprocess:
    n_cores = 30 #multiprocessing.cpu_count()
    pool = multiprocessing.Pool(processes=n_cores)

inputs = []
with open(query_list, 'r') as f:
    for line in f:
        inputs.append((line.rstrip(), outdir))

if multiprocess:
    # process queries in parallel
    outputs = list(pool.starmap(processQuery_wrapper, inputs))
else:
    for i in inputs:
        processQuery_wrapper(i[0], d, i[1], runtime_budget)
# Out:
# STARTING PROCESSING
# Processing data/ScannedDataset/p111/p111-1.jpg
# 880
# 1.161064624786377
# Processing data/ScannedDataset/p111/p111-0.jpg
# 888
# 0.9722204208374023
# Processing data/ScannedDataset/p141/p141-1.jpg
# 652
# 0.8689262866973877
# Processing data/ScannedDataset/p141/p141-2.jpg
# 844
# 1.0336666107177734
# Processing data/ScannedDataset/p141/p141-4.jpg
# 900
# 0.9183859825134277
# Processing data/ScannedDataset/p141/p141-0.jpg
# 309
# 1.102367877960205
# Processing data/ScannedDataset/p141/p141-3.jpg
# 968
# 0.7632803916931152
# Processing data/ScannedDataset/p45/p45-1.jpg
# 960
# 0.545651912689209
# Processing data/ScannedDataset/p45/p45-2.jpg
# 840
# 0.5218989849090576
# Processing data/ScannedDataset/p45/p45-3.jpg
# 952
# 0.5320672988891602
# Processing data/ScannedDataset/p45/p45-0.jpg
# 804
# 0.5523898601531982
# Processing data/ScannedDataset/p181/p181-7.jpg
# 744
# 0.792820930480957
# Processing data/ScannedDataset/p181/p181-0.jpg
# 744
# 0.5583536624908447
# Processing data/ScannedDataset/p181/p181-5.jpg
# 945
# 0.8359284400939941
# Processing data/ScannedDataset/p181/p181-3.jpg
# 920
# 0.7691810131072998
# Processing data/ScannedDataset/p181/p181-8.jpg
# 973
# 0.8023192882537842
# Processing data/ScannedDataset/p181/p181-2.jpg
# 602
# 0.874152421951294
# Processing data/ScannedDataset/p181/p181-4.jpg
# 885
# 0.7900071144104004
# Processing data/ScannedDataset/p181/p181-9.jpg
# 830
# 0.8330886363983154
# Processing data/ScannedDataset/p181/p181-6.jpg
# 564
# 0.894340991973877
# Processing data/ScannedDataset/p181/p181-1.jpg
# 909
# 0.5986824035644531
# Processing data/ScannedDataset/p185/p185-1.jpg
# 803
# 0.9613180160522461
# Processing data/ScannedDataset/p185/p185-0.jpg
# 775
# 1.0235095024108887
# Processing data/ScannedDataset/p185/p185-3.jpg
# 976
# 0.9579522609710693
# Processing data/ScannedDataset/p185/p185-4.jpg
# 938
# 0.5197813510894775
# Processing data/ScannedDataset/p185/p185-2.jpg
# 845
# 1.2644503116607666
# Processing data/ScannedDataset/p51/p51-1.jpg
# 888
# 1.580622673034668
# Processing data/ScannedDataset/p51/p51-0.jpg
# 930
# 1.6279737949371338
# Processing data/ScannedDataset/p81/p81-2.jpg
# 955
# 0.6795752048492432
# Processing data/ScannedDataset/p81/p81-4.jpg
# 728
# 0.8032913208007812
# Processing data/ScannedDataset/p81/p81-6.jpg
# 873
# 0.6852576732635498
# Processing data/ScannedDataset/p81/p81-8.jpg
# 924
# 0.580913782119751
# Processing data/ScannedDataset/p81/p81-0.jpg
# 909
# 0.6443383693695068
# Processing data/ScannedDataset/p81/p81-5.jpg
# 954
# 0.8354482650756836
# Processing data/ScannedDataset/p81/p81-3.jpg
# 895
# 0.8966488838195801
# Processing data/ScannedDataset/p81/p81-7.jpg
# 963
# 0.6094324588775635
# Processing data/ScannedDataset/p81/p81-1.jpg
# 860
# 0.6432175636291504
# Processing data/ScannedDataset/p171/p171-3.jpg
# 843
# 0.8953194618225098
# Processing data/ScannedDataset/p171/p171-0.jpg
# 476
# 1.1582655906677246
# Processing data/ScannedDataset/p171/p171-2.jpg
# 916
# 0.9411485195159912
# Processing data/ScannedDataset/p171/p171-1.jpg
# 705
# 0.8589622974395752
# Processing data/ScannedDataset/p171/p171-4.jpg
# 720
# 0.9694232940673828
# Processing data/ScannedDataset/p161/p161-3.jpg
# 912
# 0.40073680877685547
# Processing data/ScannedDataset/p161/p161-2.jpg
# 920
# 0.7165417671203613
# Processing data/ScannedDataset/p161/p161-5.jpg
# 725
# 0.34116315841674805
# Processing data/ScannedDataset/p161/p161-0.jpg
# 900
# 0.5722336769104004
# Processing data/ScannedDataset/p161/p161-4.jpg
# 0
# 0.2774343490600586
# Processing data/ScannedDataset/p161/p161-1.jpg
# 0
# 0.25977540016174316
# Processing data/ScannedDataset/p145/p145-3.jpg
# 944
# 0.9268386363983154
# Processing data/ScannedDataset/p145/p145-1.jpg
# 804
# 0.8733093738555908
# Processing data/ScannedDataset/p145/p145-2.jpg
# 492
# 0.3845691680908203
# Processing data/ScannedDataset/p145/p145-0.jpg
# 872
# 1.0957584381103516
# Processing data/ScannedDataset/p175/p175-5.jpg
# 873
# 0.7660362720489502
# Processing data/ScannedDataset/p175/p175-3.jpg
# 930
# 0.7665283679962158
# Processing data/ScannedDataset/p175/p175-2.jpg
# 880
# 0.7878997325897217
# Processing data/ScannedDataset/p175/p175-7.jpg
# 577
# 0.7931673526763916
# Processing data/ScannedDataset/p175/p175-8.jpg
# 880
# 0.7744662761688232
# Processing data/ScannedDataset/p175/p175-0.jpg
# 890
# 0.7655103206634521
# Processing data/ScannedDataset/p175/p175-9.jpg
# 882
# 0.7570552825927734
# Processing data/ScannedDataset/p175/p175-1.jpg
# 891
# 0.7068562507629395
# Processing data/ScannedDataset/p175/p175-11.jpg
# 873
# 0.7574169635772705
# Processing data/ScannedDataset/p175/p175-4.jpg
# 910
# 0.7677009105682373
# Processing data/ScannedDataset/p175/p175-12.jpg
# 980
# 0.8522417545318604
# Processing data/ScannedDataset/p175/p175-6.jpg
# 950
# 0.7476611137390137
# Processing data/ScannedDataset/p175/p175-10.jpg
# 980
# 0.8062393665313721
# Processing data/ScannedDataset/p175/p175-13.jpg
# 904
# 1.0247936248779297
# Processing data/ScannedDataset/p31/p31-3.jpg
# 944
# 0.8237991333007812
# Processing data/ScannedDataset/p31/p31-0.jpg
# 800
# 0.6313204765319824
# Processing data/ScannedDataset/p31/p31-2.jpg
# 928
# 0.38103222846984863
# Processing data/ScannedDataset/p31/p31-1.jpg
# 888
# 0.3747425079345703
# Processing data/ScannedDataset/p101/p101-2.jpg
# 956
# 0.9341456890106201
# Processing data/ScannedDataset/p101/p101-0.jpg
# 812
# 0.8139219284057617
# Processing data/ScannedDataset/p101/p101-1.jpg
# 910
# 0.929776668548584
# Processing data/ScannedDataset/p15/p15-3.jpg
# 932
# 0.7501177787780762
# Processing data/ScannedDataset/p15/p15-1.jpg
# 822
# 0.8227086067199707
# Processing data/ScannedDataset/p15/p15-0.jpg
# 978
# 0.9573519229888916
# Processing data/ScannedDataset/p15/p15-2.jpg
# 915
# 0.6616182327270508
# Processing data/ScannedDataset/p191/p191-0.jpg
# 694
# 0.5252478122711182
# Processing data/ScannedDataset/p191/p191-2.jpg
# 930
# 0.6773812770843506
# Processing data/ScannedDataset/p191/p191-1.jpg
# 890
# 0.5644514560699463
# Processing data/ScannedDataset/p191/p191-3.jpg
# 882
# 0.6570236682891846
# Processing data/ScannedDataset/p191/p191-4.jpg
# 882
# 0.5396804809570312
# Processing data/ScannedDataset/p91/p91-4.jpg
# 830
# 0.8789589405059814
# Processing data/ScannedDataset/p91/p91-2.jpg
# 900
# 0.9972484111785889
# Processing data/ScannedDataset/p91/p91-5.jpg
# 925
# 0.952996015548706
# Processing data/ScannedDataset/p91/p91-6.jpg
# 963
# 1.0081381797790527
# Processing data/ScannedDataset/p91/p91-3.jpg
# 920
# 1.0466029644012451
# Processing data/ScannedDataset/p91/p91-0.jpg
# 287
# 0.40862607955932617
# Processing data/ScannedDataset/p91/p91-1.jpg
# 894
# 0.9675228595733643
# Processing data/ScannedDataset/p135/p135-1.jpg
# 756
# 0.7349388599395752
# Processing data/ScannedDataset/p135/p135-3.jpg
# 756
# 0.8471400737762451
# Processing data/ScannedDataset/p135/p135-4.jpg
# 945
# 0.8059585094451904
# Processing data/ScannedDataset/p135/p135-0.jpg
# 528
# 0.5052859783172607
# Processing data/ScannedDataset/p135/p135-2.jpg
# 196
# 0.7180807590484619
# Processing data/ScannedDataset/p25/p25-1.jpg
# 900
# 0.7481310367584229
# Processing data/ScannedDataset/p25/p25-0.jpg
# 882
# 0.6845343112945557
# Processing data/ScannedDataset/p1/p1-0.jpg
# 864
# 0.5707061290740967
# Processing data/ScannedDataset/p1/p1-1.jpg
# 768
# 0.5757887363433838
# Processing data/ScannedDataset/p1/p1-3.jpg
# 848
# 0.7993946075439453
# Processing data/ScannedDataset/p1/p1-2.jpg
# 624
# 0.5883684158325195
# Processing data/ScannedDataset/p65/p65-2.jpg
# 846
# 1.0981099605560303
# Processing data/ScannedDataset/p65/p65-0.jpg
# 780
# 0.7256457805633545
# Processing data/ScannedDataset/p65/p65-1.jpg
# 922
# 0.9366040229797363
# Processing data/ScannedDataset/p125/p125-0.jpg
# 749
# 0.7389411926269531
# Processing data/ScannedDataset/p125/p125-6.jpg
# 954
# 0.6551024913787842
# Processing data/ScannedDataset/p125/p125-1.jpg
# 930
# 0.8187141418457031
# Processing data/ScannedDataset/p125/p125-4.jpg
# 920
# 0.6807355880737305
# Processing data/ScannedDataset/p125/p125-2.jpg
# 958
# 0.7153983116149902
# Processing data/ScannedDataset/p125/p125-3.jpg
# 646
# 0.42948174476623535
# Processing data/ScannedDataset/p125/p125-5.jpg
# 924
# 0.6639869213104248
# Processing data/ScannedDataset/p165/p165-1.jpg
# 915
# 0.4663090705871582
# Processing data/ScannedDataset/p165/p165-2.jpg
# 856
# 0.7199327945709229
# Processing data/ScannedDataset/p165/p165-0.jpg
# 948
# 0.6522173881530762
# Processing data/ScannedDataset/p165/p165-3.jpg
# 954
# 0.8522710800170898
# Processing data/ScannedDataset/p115/p115-5.jpg
# 758
# 0.6580181121826172
# Processing data/ScannedDataset/p115/p115-4.jpg
# 820
# 0.6280636787414551
# Processing data/ScannedDataset/p115/p115-1.jpg
# 912
# 0.7400918006896973
# Processing data/ScannedDataset/p115/p115-2.jpg
# 882
# 0.6220917701721191
# Processing data/ScannedDataset/p115/p115-3.jpg
# 936
# 0.7719602584838867
# Processing data/ScannedDataset/p115/p115-0.jpg
# 924
# 0.6236939430236816
# Processing data/ScannedDataset/p61/p61-2.jpg
# 808
# 0.8744995594024658
# Processing data/ScannedDataset/p61/p61-3.jpg
# 965
# 0.9513888359069824
# Processing data/ScannedDataset/p61/p61-1.jpg
# 550
# 0.8405623435974121
# Processing data/ScannedDataset/p61/p61-9.jpg
# 840
# 1.1030232906341553
# Processing data/ScannedDataset/p61/p61-10.jpg
# 978
# 1.193221092224121
# Processing data/ScannedDataset/p61/p61-4.jpg
# 749
# 1.0386543273925781
# Processing data/ScannedDataset/p61/p61-0.jpg
# 600
# 0.32968616485595703
# Processing data/ScannedDataset/p61/p61-6.jpg
# 0
# 0.29577159881591797
# Processing data/ScannedDataset/p61/p61-7.jpg
# 975
# 0.9938640594482422
# Processing data/ScannedDataset/p61/p61-5.jpg
# 864
# 0.9051647186279297
# Processing data/ScannedDataset/p61/p61-8.jpg
# 992
# 0.3426973819732666
# Processing data/ScannedDataset/p121/p121-1.jpg
# 767
# 0.6042027473449707
# Processing data/ScannedDataset/p121/p121-0.jpg
# 888
# 0.5374252796173096
# Processing data/ScannedDataset/p121/p121-5.jpg
# 0
# 0.257037878036499
# Processing data/ScannedDataset/p121/p121-4.jpg
# 0
# 0.24637365341186523
# Processing data/ScannedDataset/p121/p121-2.jpg
# 0
# 0.2414851188659668
# Processing data/ScannedDataset/p121/p121-3.jpg
# 0
# 0.23869991302490234
# Processing data/ScannedDataset/p75/p75-2.jpg
# 0
# 0.25035572052001953
# Processing data/ScannedDataset/p75/p75-1.jpg
# 981
# 0.7734017372131348
# Processing data/ScannedDataset/p75/p75-0.jpg
# 793
# 0.5790543556213379
# Processing data/ScannedDataset/p151/p151-3.jpg
# 820
# 1.0124485492706299
# Processing data/ScannedDataset/p151/p151-0.jpg
# 844
# 0.9955799579620361
# Processing data/ScannedDataset/p151/p151-2.jpg
# 688
# 0.9348552227020264
# Processing data/ScannedDataset/p151/p151-1.jpg
# 870
# 0.3689734935760498
# Processing data/ScannedDataset/p55/p55-2.jpg
# 414
# 0.4106917381286621
# Processing data/ScannedDataset/p55/p55-0.jpg
# 0
# 0.29280900955200195
# Processing data/ScannedDataset/p55/p55-1.jpg
# 363
# 0.47209787368774414
# Processing data/ScannedDataset/p71/p71-0.jpg
# 835
# 0.8300373554229736
# Processing data/ScannedDataset/p71/p71-1.jpg
# 782
# 0.5745790004730225
# Processing data/ScannedDataset/p41/p41-1.jpg
# 931
# 0.6774907112121582
# Processing data/ScannedDataset/p41/p41-0.jpg
# 708
# 0.6678669452667236
# Processing data/ScannedDataset/p85/p85-2.jpg
# 936
# 0.6585726737976074
# Processing data/ScannedDataset/p85/p85-4.jpg
# 859
# 0.770143985748291
# Processing data/ScannedDataset/p85/p85-0.jpg
# 950
# 0.6185588836669922
# Processing data/ScannedDataset/p85/p85-1.jpg
# 816
# 0.7558283805847168
# Processing data/ScannedDataset/p85/p85-3.jpg
# 762
# 0.524287223815918
# Processing data/ScannedDataset/p5/p5-4.jpg
# 819
# 0.5483555793762207
# Processing data/ScannedDataset/p5/p5-3.jpg
# 835
# 0.598517656326294
# Processing data/ScannedDataset/p5/p5-5.jpg
# 870
# 0.5792038440704346
# Processing data/ScannedDataset/p5/p5-1.jpg
# 889
# 0.5319943428039551
# Processing data/ScannedDataset/p5/p5-0.jpg
# 830
# 0.5358662605285645
# Processing data/ScannedDataset/p5/p5-2.jpg
# 855
# 0.6881489753723145
# Processing data/ScannedDataset/p195/p195-1.jpg
# 440
# 0.5946860313415527
# Processing data/ScannedDataset/p195/p195-0.jpg
# 816
# 0.9156508445739746
# Processing data/ScannedDataset/p35/p35-0.jpg
# 890
# 0.8805127143859863
# Processing data/ScannedDataset/p35/p35-1.jpg
# 956
# 1.0780177116394043
# Processing data/ScannedDataset/p131/p131-5.jpg
# 893
# 0.4525167942047119
# Processing data/ScannedDataset/p131/p131-2.jpg
# 375
# 0.2923424243927002
# Processing data/ScannedDataset/p131/p131-1.jpg
# 923
# 0.3115832805633545
# Processing data/ScannedDataset/p131/p131-10.jpg
# 720
# 0.884286642074585
# Processing data/ScannedDataset/p131/p131-3.jpg
# 270
# 0.3381509780883789
# Processing data/ScannedDataset/p131/p131-0.jpg
# 0
# 0.25194382667541504
# Processing data/ScannedDataset/p131/p131-6.jpg
# 0
# 0.29769349098205566
# Processing data/ScannedDataset/p131/p131-8.jpg
# 870
# 0.9302189350128174
# Processing data/ScannedDataset/p131/p131-7.jpg
# 940
# 0.5399601459503174
# Processing data/ScannedDataset/p131/p131-4.jpg
# 960
# 0.41266632080078125
# Processing data/ScannedDataset/p131/p131-9.jpg
# 900
# 0.30176711082458496
# Processing data/ScannedDataset/p131/p131-11.jpg
# 568
# 0.2910747528076172
# Processing data/ScannedDataset/p155/p155-6.jpg
# 864
# 0.9531540870666504
# Processing data/ScannedDataset/p155/p155-1.jpg
# 760
# 0.4673900604248047
# Processing data/ScannedDataset/p155/p155-0.jpg
# 868
# 0.36876392364501953
# Processing data/ScannedDataset/p155/p155-5.jpg
# 924
# 0.34521055221557617
# Processing data/ScannedDataset/p155/p155-2.jpg
# 781
# 0.33060765266418457
# Processing data/ScannedDataset/p155/p155-4.jpg
# 744
# 0.35242390632629395
# Processing data/ScannedDataset/p155/p155-3.jpg
# 600
# 0.3170502185821533
# Processing data/ScannedDataset/p21/p21-8.jpg
# 942
# 0.9573447704315186
# Processing data/ScannedDataset/p21/p21-5.jpg
# 880
# 0.8757233619689941
# Processing data/ScannedDataset/p21/p21-4.jpg
# 768
# 0.9849700927734375
# Processing data/ScannedDataset/p21/p21-2.jpg
# 530
# 1.141733169555664
# Processing data/ScannedDataset/p21/p21-3.jpg
# 948
# 0.8168642520904541
# Processing data/ScannedDataset/p21/p21-1.jpg
# 936
# 0.8541884422302246
# Processing data/ScannedDataset/p21/p21-7.jpg
# 846
# 0.814979076385498
# Processing data/ScannedDataset/p21/p21-0.jpg
# 960
# 0.8589925765991211
# Processing data/ScannedDataset/p21/p21-6.jpg
# 954
# 0.8620443344116211
# Processing data/ScannedDataset/p11/p11-12.jpg
# 605
# 0.3356814384460449
# Processing data/ScannedDataset/p11/p11-10.jpg
# 760
# 0.3276693820953369
# Processing data/ScannedDataset/p11/p11-7.jpg
# 959
# 0.5221199989318848
# Processing data/ScannedDataset/p11/p11-8.jpg
# 495
# 0.39695215225219727
# Processing data/ScannedDataset/p11/p11-5.jpg
# 799
# 0.37611818313598633
# Processing data/ScannedDataset/p11/p11-1.jpg
# 980
# 0.9400804042816162
# Processing data/ScannedDataset/p11/p11-9.jpg
# 142
# 0.32494258880615234
# Processing data/ScannedDataset/p11/p11-4.jpg
# 664
# 0.3244614601135254
# Processing data/ScannedDataset/p11/p11-2.jpg
# 825
# 0.3692154884338379
# Processing data/ScannedDataset/p11/p11-3.jpg
# 724
# 0.8719062805175781
# Processing data/ScannedDataset/p11/p11-11.jpg
# 840
# 0.8202548027038574
# Processing data/ScannedDataset/p11/p11-6.jpg
# 831
# 1.1301789283752441
# Processing data/ScannedDataset/p11/p11-0.jpg
# 830
# 0.32864809036254883
# Processing data/ScannedDataset/p95/p95-0.jpg
# 0
# 0.24417567253112793
# Processing data/ScannedDataset/p95/p95-1.jpg
# 62
# 0.3378727436065674
# Processing data/ScannedDataset/p95/p95-2.jpg
# 0
# 0.2734544277191162
# Processing data/ScannedDataset/p105/p105-1.jpg
# 936
# 0.8477988243103027
# Processing data/ScannedDataset/p105/p105-4.jpg
# 860
# 0.697202205657959
# Processing data/ScannedDataset/p105/p105-2.jpg
# 816
# 0.7269163131713867
# Processing data/ScannedDataset/p105/p105-3.jpg
# 804
# 0.5629346370697021
# Processing data/ScannedDataset/p105/p105-0.jpg
# 906
# 0.819282054901123
# Processing data/ScannedDataset/p105/p105-5.jpg
# 918
# 0.6711218357086182
# Processing data/ScannedDataset/p105/p105-6.jpg
# 888
# 0.6841058731079102
